# %%
pwd
# Out:
# '/Users/kenzaelhoussaini/code/Jehadel/reestimator/notebooks/Kenza'

# %%
cd ../..
# Out:
# /Users/kenzaelhoussaini/code/Jehadel/reestimator

# %%
ls
# Out:
# Dockerfile                  raw_data/
# MANIFEST.in                 ree_website/
# Makefile                    reestimator/
# README.md                   requirements.txt
# api/                        scripts/
# description_equipement.pdf  setup.py
# notebooks/                  tests/
# predict.py

# %%
cd reestimator/Mysql_mgmt
# Out:
# /Users/kenzaelhoussaini/code/Jehadel/reestimator/reestimator/Mysql_mgmt

# %%
ls
# Out:
# __init__.py  get_data.py  testing.py

# %%
from reestimator.Mysql_mgmt.get_data import Data_loading
print(Data_loading().show_tables())
# Out:
# Engine(mysql+pymysql://Estimators:***@34.77.88.127:3306/Housing_France)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/reestimator/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~/.pyenv/versions/3.8.6/envs/reestimator/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/.pyenv/versions/3.8.6/envs/reestimator/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ...
